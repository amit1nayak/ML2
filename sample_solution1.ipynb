# %% [markdown]
# ##  MTech Graded Assessment
# ## Subject : ML-2
# ## Marks: 40
# ## Time : 4 Hours

# %% [markdown]
# ### DATASET:
#
# This dataset contains daily weather observations from numerous Australian weather stations.
#
# The target variable is RainTomorrow. This means: Did it rain the next day? Yes or No.

# %% [markdown]
# ### ATTRIBUTE INFORMATION:

# %% [markdown]
# 1. 'Date'= The date of observation
#
# 2. 'Location'=The common name of the location of the weather station
#
# 3. 'MinTemp'= The minimum temperature in degrees celsius
#
# 4. 'MaxTemp'= The maximum temperature in degrees celsius
#
# 5. 'Rainfall' = The amount of rainfall recorded for the day in mm
#
# 6. 'Evaporation'= The so-called Class A pan evaporation (mm) in the 24 hours to 9am
#
# 7. 'Sunshine'= The number of hours of bright sunshine in the day.
#
# 8. 'WindGustDir'= The direction of the strongest wind gust in the 24 hours to midnight
#
# 9. 'WindGustSpeed'= The speed (km/h) of the strongest wind gust in the 24 hours to midnight
#
# 10. 'WindDir9am'= Direction of the wind at 9am
#
# 11. 'WindDir3pm' = Direction of the wind at 3pm
#
# 12. 'WindSpeed9am'= Wind speed (km/hr) averaged over 10 minutes prior to 9am
#
# 13. 'WindSpeed3pm'=  Wind speed (km/hr) averaged over 10 minutes prior to 3pm
#
# 14. 'Humidity9am'= Humidity (percent) at 9am
#
# 15. 'Humidity3pm'= Humidity (percent) at 3pm
#
# 16. 'Pressure9am'= Atmospheric pressure (hpa) reduced to mean sea level at 9am
#
# 17. 'Pressure3pm'= Atmospheric pressure (hpa) reduced to mean sea level at 3pm
#
# 18. 'Cloud9am'= Fraction of sky obscured by cloud at 9am. This is measured in "oktas", which are a unit of eigths. It records how many eigths of the sky are
#
# 19. 'Cloud3pm'= Fraction of sky obscured by cloud (in "oktas": eighths) at 3pm. See Cload9am for a description of the values
#
# 20. 'Temp9am'= Temperature (degrees C) at 9am
#
# 21. 'Temp3pm'=  Temperature (degrees C) at 3pm
#
# 22. 'RainToday'=  Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
#
# 23. 'RISK_MM'= The amount of next day rain in mm. Used to create response variable RainTomorrow. A kind of measure of the "risk".
#
# 24. 'RainTomorrow'= The target variable. Did it rain tomorrow?

# %% [markdown]
# ### 1.	Read the dataset (tab, csv, xls, txt, inbuilt dataset)

# %%
# Kindly change the below cells from markdown to code and execute it

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('weather.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-051543e05a8c> in <module>
# ----> 1 df=pd.read_csv('weather.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
# ...

# %% [markdown]
# import csv
#
# with open("data_set.csv","r")as file:
#
#     reader=csv.reader(file)
#
# df=pd.read_csv("data_set.csv")
#
# df.head()

# %% [markdown]
# ### 2.	Summarize important observations from the data set (5 Marks)
#
# Some pointers which would help you, but don’t be limited by these
#
# a.	Find out number of rows; no. & types of variables (continuous, categorical etc.)
#
# b.	Calculate five-point summary for numerical variables
#
# c.	Summarize observations for categorical variables – no. of categories, % observations in each category

# %%
#a) print shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 24 columns):
# Date             1040 non-null object
# Location         1040 non-null object
# MinTemp          1035 non-null float64
# MaxTemp          1035 non-null float64
# Rainfall         1029 non-null float64
# Evaporation      582 non-null float64
# Sunshine         533 non-null float64
# WindGustDir      969 non-null object
# WindGustSpeed    969 non-null float64
# WindDir9am       981 non-null object
# WindDir3pm       1014 non-null object
# WindSpeed9am     1032 non-null float64
# WindSpeed3pm     1023 non-null float64
# Humidity9am      1031 non-null float64
# Humidity3pm      1016 non-null float64
# Pressure9am      929 non-null float64
# Pressure3pm      932 non-null float64
# Cloud9am         613 non-null float64
# Cloud3pm         597 non-null float64
# Temp9am          1034 non-null float64
# Temp3pm          1022 non-null float64
# RainToday        1029 non-null object
# ...

# %% [markdown]
# Interpretation :
#
#   * Given dataset has 1040 instances and 24 features.
#   * This dataset has 17 numerical features and 7 categorical features.
#   * Dataset has missing values, so use appropriate technique to treat the missing values.
#   * All features have the correct format.. so no need to change dtypes.

# %%
#b) 
df.describe(include='all')
# Out:
#               Date    Location      MinTemp      MaxTemp    Rainfall  \
# count         1040        1040  1035.000000  1035.000000  1029.00000
# unique         890          49          NaN          NaN         NaN
# top     23-07-2016  SalmonGums          NaN          NaN         NaN
# freq             4          33          NaN          NaN         NaN
# mean           NaN         NaN    12.008019    23.055942     2.18552
# std            NaN         NaN     6.176816     6.809834     7.50278
# min            NaN         NaN    -4.100000    -0.800000     0.00000
# 25%            NaN         NaN     7.500000    17.900000     0.00000
# 50%            NaN         NaN    11.800000    22.500000     0.00000
# 75%            NaN         NaN    16.350000    27.700000     0.80000
# max            NaN         NaN    28.600000    43.900000   121.40000
#
#         Evaporation    Sunshine WindGustDir  WindGustSpeed WindDir9am  ...  \
# ...

# %% [markdown]
# Interpretation:
#
#     * Drop date feature.. because it has unique values.
#     * Risk_MM and Rainfall features has too much variation.
#     * Location-SalmonGums is recored more times(33 times).
#     * WindGustDir= West recored more times (80 times).

# %%
#c) 

cat_feat=list(df.drop(columns=['Date']).select_dtypes(include='object').columns)

for col in cat_feat:
    sns.countplot(df[col])
    plt.xticks(rotation=90)
    plt.show()

# %%
#Check correlation


plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='rainbow_r')

# %% [markdown]
# ### 3.	Check for defects in the data. Perform necessary actions to ‘fix’ these defects (5 Marks)
#
# Some pointers which would help you, but don’t be limited by these
#
# a.	Do variables have missing/null values?
#
# b.	Do variables have outliers?
#
# c.	Is the Target distributed evenly? Is it a defect? If Yes, what steps are being taken to rectify the problem.

# %%
#a)

df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            5
# MaxTemp            5
# Rainfall          11
# Evaporation      458
# Sunshine         507
# WindGustDir       71
# WindGustSpeed     71
# WindDir9am        59
# WindDir3pm        26
# WindSpeed9am       8
# WindSpeed3pm      17
# Humidity9am        9
# Humidity3pm       24
# Pressure9am      111
# Pressure3pm      108
# Cloud9am         427
# Cloud3pm         443
# Temp9am            6
# Temp3pm           18
# RainToday         11
# RISK_MM            0
# RainTomorrow       0
# dtype: int64

# %% [markdown]
# Interpretation:
#
#     So many missing values are there so we need to treat this missing values.

# %%
df['Pressure9am']=df['Pressure9am'].fillna(df['Pressure9am'].mean())
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm'].mean())
df['Temp9am']=df['Temp9am'].fillna(df['Temp9am'].mean())
df['Temp3pm']=df['Temp3pm'].fillna(df['Temp3pm'].mean())
df['Cloud9am']=df['Cloud9am'].fillna(df['Cloud9am'].mode()[0])
df['Cloud3pm']=df['Cloud3pm'].fillna(df['Cloud3pm'].mode()[0])

# %%
df['WindDir9am']=df['WindDir9am'].fillna(df['WindDir9am'].mode()[0])
df['WindDir3pm']=df['WindDir3pm'].fillna(df['WindDir3pm'].mode()[0])
df['Rainfall']=df['Rainfall'].fillna(df['Rainfall'].mean())
df['Evaporation']=df['Evaporation'].fillna(df['Evaporation'].mean())
df['Sunshine']=df['Sunshine'].fillna(df['Sunshine'].mean())

# %%
df['MinTemp']=df['MinTemp'].fillna(df['MinTemp'].mean())
df['MaxTemp']=df['MaxTemp'].fillna(df['MaxTemp'].mean())

# %%
df['WindGustDir']=df['WindGustDir'].fillna(df['WindGustDir'].mode()[0])
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          0
# WindGustDir       0
# WindGustSpeed     0
# WindDir9am        0
# WindDir3pm        0
# WindSpeed9am      0
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday        11
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df['WindSpeed3pm']=df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())
df['Humidity9am']=df['Humidity9am'].fillna(df['Humidity9am'].mean())
df['Humidity3pm']=df['Humidity3pm'].fillna(df['Humidity3pm'].mean())

# %%
df['RainToday'].isnull().index
# Out:
# RangeIndex(start=0, stop=1040, step=1)

# %%
#drop those rows have nan values in RainToday column
df['RainToday']=df['RainToday'].dropna()
df.reset_index(drop=True).shape
# Out:
# (1040, 24)

# %%
df.dropna(inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull())

# %% [markdown]
# Interpretation:Dataset is free of missing values.

# %%
df.reset_index(drop=True).shape
# Out:
# (1029, 24)

# %%
#b)

plt.figure(figsize=(15,10))
df.boxplot()

# %% [markdown]
# Interpretation:
#
#     * From the above graphs infers that is dataset features has outliers.

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
#c) 

sns.countplot(df['RainTomorrow'])

# %% [markdown]
# Interpretation:
#
#    * This dataset is imbalanced one .. so `SMOTE` technique to overcome this.

# %% [markdown]
# ### 4.	Summarize relationships among variables (5 marks)
# a.	Plot relevant categorical plots. Find out which are the variables most correlated or appear to be in causation with Target? Do you want to exclude some variables from the model based on this analysis? What other actions will you take?
#
#
# b.	Plot all independent variables with the target & find out the relationship? Perform the Relevant Tests to find out if the Independent variables are associated with the Target Variable.
#
#  Hint: based on your observations you may want to transform features or create additional features.

# %%
cat_data=df.drop(columns=['RainTomorrow']).select_dtypes(include='object')
num_data=df.select_dtypes(exclude='object')

target=df['RainTomorrow']

# %%
cat_data=cat_data.drop(columns=['Date'])

# %%
#a)
for col in cat_data.columns:
    result=pd.crosstab(columns=target,index=cat_data[col])
    print(result,'\n')
# Out:
# RainTomorrow      No  Yes
# Location
# Adelaide          19    2
# Albany            13    6
# Albury            18    3
# AliceSprings      15    3
# BadgerysCreek     20    5
# Ballarat           8    4
# Bendigo           15    2
# Brisbane          19    5
# Cairns            11    5
# Canberra          14    4
# Cobar             16    0
# CoffsHarbour      19    2
# Dartmoor          18    5
# Darwin            23    6
# GoldCoast         14    4
# Hobart            24    2
# Katherine          8    1
# Launceston        23    8
# Melbourne         16    5
# MelbourneAirport  15    9
# Mildura           15    2
# Moree             19    2
# MountGambier      20    6
# MountGinini       10    7
# Newcastle         21    1
# Nhil               8    2
# NorahHead         20    9
# NorfolkIsland     13    9
# Nuriootpa         14    5
# PearceRAAF        14    1
# Penrith           14    3
# Perth             16   10
# PerthAirport      22    3
# Portland          15    3
# ...

# %%
#b)
for col in num_data.columns:
    sns.scatterplot(x=num_data[col],y=target)
    plt.show()

# %%
cat_data.columns
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], dtype='object')

# %%
#Do encoding 

from sklearn.preprocessing import LabelEncoder
label_enc=LabelEncoder()

cat_data['Location']=label_enc.fit_transform(cat_data['Location'])
cat_data['WindGustDir']=label_enc.fit_transform(cat_data['WindGustDir'])
cat_data['WindDir9am']=label_enc.fit_transform(cat_data['WindDir9am'])
cat_data['WindDir3pm']=label_enc.fit_transform(cat_data['WindDir3pm'])
cat_data['RainToday']=label_enc.fit_transform(cat_data['RainToday'])

# %%
cat_data.head(2)
# Out:
#    Location  WindGustDir  WindDir9am  WindDir3pm  RainToday
# 0        47            8          11          12          1
# 1        32           15          11          15          1

# %%
#Now conacatenate both cat_data and num_data

final_data=pd.concat([cat_data,num_data],axis=1)
final_data.head(2)
# Out:
#    Location  WindGustDir  WindDir9am  WindDir3pm  RainToday  MinTemp  MaxTemp  \
# 0        47            8          11          12          1     16.0     20.4
# 1        32           15          11          15          1     18.5     25.9
#
#    Rainfall  Evaporation   Sunshine  ...  WindSpeed3pm  Humidity9am  \
# 0       8.2     5.183505   7.606379  ...          20.0         69.0
# 1      16.0     5.400000  11.800000  ...          22.0         60.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0         92.0       1018.5       1017.6       1.0       8.0     17.4
# 1         36.0       1004.6       1003.6       7.0       1.0     22.2
#
#    Temp3pm  RISK_MM
# 0     15.6     78.6
# 1     25.1      0.0
#
# [2 rows x 22 columns]

# %% [markdown]
# ### 5.	Split dataset into train and test (70:30) (1 mark)
# a.	Are both train and test representative of the overall data? How would you ascertain this statistically?

# %%
print(final_data.shape)
print(target.shape)
# Out:
# (1029, 22)
# (1029,)

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest=train_test_split(final_data,target,test_size=0.3,random_state=20)

# %%
#check dimensions

print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (720, 22)
# (309, 22)
# (720,)
# (309,)

# %% [markdown]
# ### 6.	Fit a base model and explain the reason of selecting that model. Please write your key observations (5 marks)
#
# a.	What is the overall Accuracy? Please comment on whether it is good or not.
#
# b.	What is Precision, Recall and F1 Score and what will be the optimization objective keeping in mind the problem statement.
#
# c.	Which variables are significant?
#
# d.	What is Cohen’s Kappa Value and what inference do you make from the model
#
# e.	Which other key model output parameters do you want to look at?

# %%
#models without smote technique

import  statsmodels.api as sm

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics  import accuracy_score

models=list()
models.append(LogisticRegression())
models.append(KNeighborsClassifier())
models.append(DecisionTreeClassifier())
models.append(GaussianNB())


for mod in models:
    print('Model name :',mod)
    clf=mod
    model=clf.fit(xtrain,ytrain)
    print('accuracy score ',accuracy_score(ytest,model.predict(xtest)))
# Out:
# Model name : LogisticRegression()
# accuracy score  0.9935275080906149
# Model name : KNeighborsClassifier()
# accuracy score  0.8705501618122977
# Model name : DecisionTreeClassifier()
# accuracy score  1.0
# Model name : GaussianNB()
# accuracy score  0.941747572815534
# /home/deploy/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#smote technique

from imblearn.over_sampling import SMOTE

smote=SMOTE()
xtrain_smote,ytrain_smote=smote.fit_sample(xtrain,ytrain)

print('Before dimensions :')
print(xtrain.shape)
print(ytrain.shape)

print('---')
print('After SMOTE: ')
print(xtrain_smote.shape)
print(ytrain_smote.shape)
# Out:
# Before dimensions :
# (720, 22)
# (720,)
# ---
# After SMOTE:
# (1150, 22)
# (1150,)

# %%
#models with smote technique
models=list()
models.append(LogisticRegression())
models.append(KNeighborsClassifier())
models.append(DecisionTreeClassifier())
models.append(GaussianNB())


for mod in models:
    print('Model name :',mod)
    clf=mod
    model=clf.fit(xtrain_smote,ytrain_smote)
    print('accuracy score ',accuracy_score(ytest,model.predict(xtest)))
# Out:
# Model name : LogisticRegression()
# accuracy score  0.9870550161812298
# Model name : KNeighborsClassifier()
# accuracy score  0.7443365695792881
# Model name : DecisionTreeClassifier()
# accuracy score  1.0
# Model name : GaussianNB()
# accuracy score  0.9223300970873787
# /home/deploy/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# Interpretation: LogisticRegression model is giving the best.. Hence model is good.

# %%
clf=LogisticRegression()
model=clf.fit(xtrain_smote,ytrain_smote)
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
#b)
from sklearn.metrics import classification_report
print(classification_report(ytest,model.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.99      1.00      0.99       247
#          Yes       0.98      0.95      0.97        62
#
#     accuracy                           0.99       309
#    macro avg       0.99      0.97      0.98       309
# weighted avg       0.99      0.99      0.99       309

# %% [markdown]
# Interpretation:
#
#
#     Accuracy_score=0.99
#     Precison for 'yes' class =0.98
#     Precison for 'No' class =0.99
#     F1_score for 'yes' class =0.97
#     F1_score for 'No' class =0.99
#     Recall for 'No' class =1.00
#     Recall for 'yes' class =0.95

# %%
#c)
model.coef_
# Out:
# array([[ 4.15058294e-02,  4.13196444e-03,  2.82034503e-01,
#         -3.01416854e-01, -5.41198067e-02, -1.36209128e-01,
#          1.16180206e-02, -1.99374295e-02, -3.12294462e-01,
#         -3.69420353e-01, -1.38429754e-03,  6.59415345e-02,
#         -9.40455926e-03, -7.15616967e-03,  3.47576212e-02,
#          2.37137232e-01, -2.45669807e-01, -1.43526160e-01,
#          3.26681849e-01,  1.96922368e-03,  1.52230481e-01,
#          4.89879199e+00]])

# %%
model.intercept_
# Out:
# array([0.00148028])

# %%
#d)
from sklearn.metrics import cohen_kappa_score

print(cohen_kappa_score(ytest,model.predict(xtest)))
# Out:
# 0.9591512988300614

# %% [markdown]
# Interpretation:
#
#     This score indicates model is almost perfect agreement b/w  prediction values and actual values.

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(ytest,model.predict(xtest)))
# Out:
# [[246   1]
#  [  3  59]]

# %%
from sklearn.metrics import roc_auc_score
ypred_proba=model.predict_proba(xtest)
print('roc_auc_score:',roc_auc_score(ytest,ypred_proba[:,1]))
# Out:
# roc_auc_score: 0.9992817030168473

# %% [markdown]
# ### 7.	How do you improve overall efficiency of the model? Write clearly the changes that you will make before re-fitting the model. Fit the final model. (15 marks)
# Please feel free to have any number of iterations to get to the final answer. Marks are awarded based on the quality of final model you are able to achieve.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
models=list()
models.append(RandomForestClassifier())
models.append(AdaBoostClassifier())
models.append(GradientBoostingClassifier())
models.append(XGBClassifier())


for mod in models:
    print('Model name :',mod)
    clf=mod
    tree_model=clf.fit(xtrain_smote,ytrain_smote)
    print('accuracy score ',accuracy_score(ytest,tree_model.predict(xtest)))
    print('cm :','\n',confusion_matrix(ytest,tree_model.predict(xtest)))
    print('\n')
# Out:
# Model name : RandomForestClassifier()
# accuracy score  1.0
# cm :
#  [[247   0]
#  [  0  62]]
#
#
# Model name : AdaBoostClassifier()
# accuracy score  1.0
# cm :
#  [[247   0]
#  [  0  62]]
#
#
# Model name : GradientBoostingClassifier()
# accuracy score  1.0
# cm :
#  [[247   0]
#  [  0  62]]
#
#
# Model name : XGBClassifier()
# accuracy score  1.0
# cm :
#  [[247   0]
#  [  0  62]]

# %%
from sklearn.feature_selection import RFECV
rfc=RandomForestClassifier()
rfe_model=RFECV(estimator=rfc)
rfe_feat=rfe_model.fit(xtrain,ytrain)

rank=pd.DataFrame()
rank['Rank']=rfe_feat.ranking_
rank['Features']=xtrain.columns
rank.sort_values('Rank')
# Out:
#     Rank       Features
# 21     1        RISK_MM
# 14     2    Humidity3pm
# 7      3       Rainfall
# 10     4  WindGustSpeed
# 20     5        Temp3pm
# 12     6   WindSpeed3pm
# 13     7    Humidity9am
# 18     8       Cloud3pm
# 6      9        MaxTemp
# 15    10    Pressure9am
# 9     11       Sunshine
# 16    12    Pressure3pm
# 19    13        Temp9am
# 5     14        MinTemp
# 4     15      RainToday
# 11    16   WindSpeed9am
# 8     17    Evaporation
# 0     18       Location
# 3     19     WindDir3pm
# 2     20     WindDir9am
# 1     21    WindGustDir
# 17    22       Cloud9am

# %%
rank[rank['Rank']==1]
# Out:
#     Rank Features
# 21     1  RISK_MM

# %%
final_data.columns
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday',
#        'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RISK_MM'],
#       dtype='object')

# %%
#drop location
final_data.drop(columns='Location',inplace=True)
# Out:
# (720, 21)
# (309, 21)
# (720,)
# (309,)

# %%
final_data.drop(columns='RISK_MM',inplace=True)

# %%
xtrain,xtest,ytrain,ytest=train_test_split(final_data,target,test_size=0.3,random_state=20)

print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (720, 20)
# (309, 20)
# (720,)
# (309,)

# %%
rfc=RandomForestClassifier()
rfc.fit(xtrain,ytrain)
print('accuracy score for train :',rfc.score(xtrain,ytrain))
print('accuracy score for test :',accuracy_score(ytest,rfc.predict(xtest)))
# Out:
# accuracy score for train : 1.0
# accuracy score for test : 0.8543689320388349

# %%
#Hyperparameter tuning

# %%
#criterion='entropy'
rfc2=RandomForestClassifier(n_estimators=1000,criterion='gini', max_depth=4,min_samples_split=3,min_samples_leaf=3, max_leaf_nodes=4,random_state=20,n_jobs=-1)
rfc2.fit(xtrain,ytrain)
print('accuracy score for train :',rfc2.score(xtrain,ytrain))
print('accuracy score for test :',accuracy_score(ytest,rfc2.predict(xtest)))
# Out:
# accuracy score for train : 0.8416666666666667
# accuracy score for test : 0.8381877022653722

# %%
#criterion='gini'
rfc3=RandomForestClassifier(n_estimators=1000,criterion='entropy', max_depth=4,min_samples_split=3,min_samples_leaf=3, max_leaf_nodes=4,random_state=20)
rfc3.fit(xtrain,ytrain)
print('accuracy score for train :',rfc3.score(xtrain,ytrain))
print('accuracy score for test :',accuracy_score(ytest,rfc3.predict(xtest)))
# Out:
# accuracy score for train : 0.8347222222222223
# accuracy score for test : 0.8187702265372169

# %%
#This model is giving the best result

# %% [markdown]
# ### 8.	Summarize as follows (4 marks)
#
# 1.	Summarize the overall fit of the model and list down the measures to prove that it is a good model
#
# 2.	Write down a business interpretation/explanation of the model – which variables are affecting the target the most and explain the relationship. Feel free to use charts or graphs to explain.
#
# 3.	What changes from the base model had the most effect on model performance?
#
# 4.	What are the key risks to your results and interpretation?

# %%
#1)
rfc2=RandomForestClassifier(n_estimators=1000,criterion='entropy', max_depth=4,min_samples_split=3,min_samples_leaf=3, max_leaf_nodes=4,random_state=20)
rfc2.fit(xtrain,ytrain)
print('accuracy score for train :',rfc2.score(xtrain,ytrain))
print('accuracy score for test :',accuracy_score(ytest,rfc2.predict(xtest)))
# Out:
# accuracy score for train : 0.8347222222222223
# accuracy score for test : 0.8187702265372169

# %%
print(classification_report(ytest,rfc2.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      1.00      0.90       247
#          Yes       0.88      0.11      0.20        62
#
#     accuracy                           0.82       309
#    macro avg       0.85      0.55      0.55       309
# weighted avg       0.83      0.82      0.76       309

# %%
print(cohen_kappa_score(ytest,rfc2.predict(xtest)))
# Out:
# 0.1615466614982073

# %%
data=pd.DataFrame()
data['feat_val']=rfc2.feature_importances_
data['feature']=xtrain.columns
data=data.sort_values('feat_val',ascending=False)
data
# Out:
#     feat_val        feature
# 13  0.311585    Humidity3pm
# 6   0.121635       Rainfall
# 9   0.109139  WindGustSpeed
# 8   0.077216       Sunshine
# 3   0.073311      RainToday
# 12  0.057859    Humidity9am
# 17  0.052553       Cloud3pm
# 19  0.040799        Temp3pm
# 15  0.037863    Pressure3pm
# 14  0.034354    Pressure9am
# 5   0.025727        MaxTemp
# 11  0.021086   WindSpeed3pm
# 7   0.009101    Evaporation
# 16  0.007045       Cloud9am
# 10  0.006844   WindSpeed9am
# 4   0.005744        MinTemp
# 18  0.002990        Temp9am
# 2   0.002111     WindDir3pm
# 1   0.002097     WindDir9am
# 0   0.000940    WindGustDir

# %%
sns.barplot(y=data['feat_val'],x=data['feature'])
plt.xticks(rotation=90)
plt.show()

# %%
xtrain.columns
# Out:
# Index(['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'MinTemp',
#        'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RISK_MM'],
#       dtype='object')

# %% [markdown]
# 'Interpretation:
#
#     *  'Humidity3pm','Rainfall','Rainfall','WindGustSpeed','RainToday','Sunshine','Humidity9am','Cloud3pm' These are the main features for predicting next days is raining or not.
#     * Risk_mm features is more correlated to target..  so thats why initial what ever built model gave accuacy score =1.
#     so  i dropped that column and randomforest model gives =0.82
